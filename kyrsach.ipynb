# %% [markdown]
# # Загружаю библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Выгружаю данные

# %%
flights = pd.read_csv(r"C:/Users/Krasnblu/Desktop/Курсач Биг дата/flights.csv")
airports = pd.read_csv(r"C:/Users/Krasnblu/Desktop/Курсач Биг дата/airports.csv")
airlines = pd.read_csv(r"C:/Users/Krasnblu/Desktop/Курсач Биг дата/airlines.csv")
l_airport_id = pd.read_csv(r"C:/Users/Krasnblu/Desktop/Курсач Биг дата/l_airport_id.csv")
l_airport = pd.read_csv(r"C:/Users/Krasnblu/Desktop/Курсач Биг дата/l_airport.csv")
# Out:
# C:\Users\Krasnblu\AppData\Local\Temp\ipykernel_6768\2877754933.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   flights = pd.read_csv(r"C:/Users/Krasnblu/Desktop/Курсач Биг дата/flights.csv")

# %%
flights
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 0                  ANC                 SEA                    5  ...
# 1                  LAX                 PBI                   10  ...
# 2                  SFO                 CLT                   20  ...
# 3                  LAX                 MIA                   20  ...
# 4                  SEA                 ANC                   25  ...
# ...                ...                 ...                  ...  ...
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0               408.0          -22.0         0          0
# 1               741.0           -9.0         0          0
# 2               811.0            5.0         0          0
# 3               756.0           -9.0         0          0
# 4               259.0          -21.0         0          0
# ...               ...            ...       ...        ...
# 5819074         753.0          -26.0         0          0
# 5819075         430.0          -16.0         0          0
# 5819076         432.0           -8.0         0          0
# 5819077         330.0          -10.0         0          0
# 5819078         442.0            2.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 0                        NaN               NaN             NaN            NaN
# 1                        NaN               NaN             NaN            NaN
# 2                        NaN               NaN             NaN            NaN
# 3                        NaN               NaN             NaN            NaN
# 4                        NaN               NaN             NaN            NaN
# ...                      ...               ...             ...            ...
# 5819074                  NaN               NaN             NaN            NaN
# 5819075                  NaN               NaN             NaN            NaN
# 5819076                  NaN               NaN             NaN            NaN
# 5819077                  NaN               NaN             NaN            NaN
# 5819078                  NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0                        NaN            NaN
# 1                        NaN            NaN
# 2                        NaN            NaN
# 3                        NaN            NaN
# 4                        NaN            NaN
# ...                      ...            ...
# 5819074                  NaN            NaN
# 5819075                  NaN            NaN
# 5819076                  NaN            NaN
# 5819077                  NaN            NaN
# 5819078                  NaN            NaN
#
# [5819079 rows x 31 columns]

# %%
flights.columns = flights.columns.str.lower()
airports.columns = airports.columns.str.lower()
airlines.columns = airlines.columns.str.lower()
l_airport_id.columns = l_airport_id.columns.str.lower()
l_airport.columns = l_airport.columns.str.lower()

# %% [markdown]
# # 1.Бизнес – анализ данных

# %% [markdown]
# ## 1.1

# %%
flights
# Out:
#          year  month  day  day_of_week airline  flight_number tail_number  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         origin_airport destination_airport  scheduled_departure  ...  \
# 0                  ANC                 SEA                    5  ...
# 1                  LAX                 PBI                   10  ...
# 2                  SFO                 CLT                   20  ...
# 3                  LAX                 MIA                   20  ...
# 4                  SEA                 ANC                   25  ...
# ...                ...                 ...                  ...  ...
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          arrival_time  arrival_delay  diverted  cancelled  \
# 0               408.0          -22.0         0          0
# 1               741.0           -9.0         0          0
# 2               811.0            5.0         0          0
# 3               756.0           -9.0         0          0
# 4               259.0          -21.0         0          0
# ...               ...            ...       ...        ...
# 5819074         753.0          -26.0         0          0
# 5819075         430.0          -16.0         0          0
# 5819076         432.0           -8.0         0          0
# 5819077         330.0          -10.0         0          0
# 5819078         442.0            2.0         0          0
#
#          cancellation_reason  air_system_delay  security_delay  airline_delay  \
# 0                        NaN               NaN             NaN            NaN
# 1                        NaN               NaN             NaN            NaN
# 2                        NaN               NaN             NaN            NaN
# 3                        NaN               NaN             NaN            NaN
# 4                        NaN               NaN             NaN            NaN
# ...                      ...               ...             ...            ...
# 5819074                  NaN               NaN             NaN            NaN
# 5819075                  NaN               NaN             NaN            NaN
# 5819076                  NaN               NaN             NaN            NaN
# 5819077                  NaN               NaN             NaN            NaN
# 5819078                  NaN               NaN             NaN            NaN
#
#          late_aircraft_delay  weather_delay
# 0                        NaN            NaN
# 1                        NaN            NaN
# 2                        NaN            NaN
# 3                        NaN            NaN
# 4                        NaN            NaN
# ...                      ...            ...
# 5819074                  NaN            NaN
# 5819075                  NaN            NaN
# 5819076                  NaN            NaN
# 5819077                  NaN            NaN
# 5819078                  NaN            NaN
#
# [5819079 rows x 31 columns]

# %%
number_flights_per_month = flights.day.groupby(flights.month).count()
number_flights_per_month = number_flights_per_month.reset_index()
number_flights_per_month.rename(columns={'day': 'flights'}, inplace=True)
number_flights_per_month.replace({1 : 'January', 2 : 'February', 3 : 'March', 4 : 'April', 5 : 'May', 6 : 'June', 7 : 'July', 8 : 'August', 9 : 'September', 10 : 'October', 11 : 'November', 12 : 'December' }, inplace = True)
number_flights_per_month
# Out:
#         month  flights
# 0     January   469968
# 1    February   429191
# 2       March   504312
# 3       April   485151
# 4         May   496993
# 5        June   503897
# 6        July   520718
# 7      August   510536
# 8   September   464946
# 9     October   486165
# 10   November   467972
# 11   December   479230

# %%
x = number_flights_per_month.month
y = number_flights_per_month.flights

fig, ax = plt.subplots()

ax.bar(x, y)

ax.set_xlabel('Месяцы',fontsize = 15)
ax.set_ylabel('Количество рейсов',fontsize = 15)

fig.set_figwidth(20)    #  ширина Figure
fig.set_figheight(10)    #  высота Figure

plt.show()

# %% [markdown]
# Пик перелетов приходится на 7 месяц, а спад наблюдается на 2 месяц.

# %% [markdown]
# ## 1.2

# %%
flights_day_of_the_week = flights.day.groupby(flights.day_of_week).count()
flights_day_of_the_week = flights_day_of_the_week.reset_index()
flights_day_of_the_week.rename(columns={'day': 'flights'}, inplace=True)
flights_day_of_the_week.replace({1 : 'Понедельник', 2 : 'Вторник', 3 : 'Среда', 4 : 'Четверг', 5 : 'Пятница', 6 : 'Суббота', 7 : 'Воскресенье' }, inplace = True)
flights_day_of_the_week
# Out:
#    day_of_week  flights
# 0  Понедельник   865543
# 1      Вторник   844600
# 2        Среда   855897
# 3      Четверг   872521
# 4      Пятница   862209
# 5      Суббота   700545
# 6  Воскресенье   817764

# %%
x = flights_day_of_the_week.day_of_week
y = flights_day_of_the_week.flights

fig, ax = plt.subplots()

ax.bar(x, y)

ax.set_xlabel('Дни недели',fontsize = 15)
ax.set_ylabel('Количество рейсов',fontsize = 15)

fig.set_figwidth(20)    #  ширина Figure
fig.set_figheight(10)    #  высота Figure

plt.show()

# %% [markdown]
# Количество рейсов по дням недели распределены в основном на рабочие дни с пн-пт, на выходных наблюдается уменьшение количества рейсов.

# %% [markdown]
# ## 1.3

# %%
from_city = flights.origin_airport.value_counts()
to_city = flights.destination_airport.value_counts()
summa_flights = from_city.append(to_city)
summa_flights
# Out:
# C:\Users\Krasnblu\AppData\Local\Temp\ipykernel_6768\53875509.py:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summa_flights = from_city.append(to_city)
# ATL      346836
# ORD      285884
# DFW      239551
# DEN      196055
# LAX      194673
#           ...
# 13964         1
# 14025         1
# 15497         1
# 12265         1
# 10666         1
# Length: 1860, dtype: int64

# %%
group_sum = summa_flights.groupby(summa_flights.index).sum()
airports_group = pd.DataFrame(group_sum.sort_values(ascending = False), columns = ['flights'])
airports_group
# Out:
#        flights
# ATL     693740
# ORD     571790
# DFW     479133
# DEN     392065
# LAX     389369
# ...        ...
# 13964        2
# 14222        2
# 12265        2
# 10666        1
# 11503        1
#
# [931 rows x 1 columns]

# %%
group_city = airports.set_index('iata_code').join(airports_group,rsuffix = ['flights'])
group_city
# Out:
#                                        airport  \
# iata_code
# ABE        Lehigh Valley International Airport
# ABI                   Abilene Regional Airport
# ABQ          Albuquerque International Sunport
# ABR                  Aberdeen Regional Airport
# ABY         Southwest Georgia Regional Airport
# ...                                        ...
# WRG                           Wrangell Airport
# WYS                     Westerly State Airport
# XNA        Northwest Arkansas Regional Airport
# YAK                            Yakutat Airport
# YUM                 Yuma International Airport
#
#                                      city state country  latitude  longitude  \
# iata_code
# ABE                             Allentown    PA     USA  40.65236  -75.44040
# ABI                               Abilene    TX     USA  32.41132  -99.68190
# ABQ                           Albuquerque    NM     USA  35.04022 -106.60919
# ABR                              Aberdeen    SD     USA  45.44906  -98.42183
# ABY                                Albany    GA     USA  31.53552  -84.19447
# ...                                   ...   ...     ...       ...        ...
# WRG                              Wrangell    AK     USA  56.48433 -132.36982
# WYS                      West Yellowstone    MT     USA  44.68840 -111.11764
# XNA        Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# YAK                               Yakutat    AK     USA  59.50336 -139.66023
# YUM                                  Yuma    AZ     USA  32.65658 -114.60597
#
#            flights
# iata_code
# ABE           4550
# ABI           4656
# ABQ          38380
# ABR           1342
# ABY           1752
# ...            ...
# WRG           1328
# WYS            416
# XNA          18567
# YAK           1324
# YUM           3755
#
# [322 rows x 7 columns]

# %%
top10_city = group_city.flights.groupby(group_city.city).sum().sort_values(ascending = False).head(10)
top10_city = top10_city.reset_index()
top10_city
# Out:
#                 city  flights
# 0            Chicago   733560
# 1            Atlanta   693740
# 2  Dallas-Fort Worth   479133
# 3            Houston   397388
# 4             Denver   392065
# 5        Los Angeles   389369
# 6           New York   386806
# 7      San Francisco   295974
# 8            Phoenix   293627
# 9          Las Vegas   266379

# %% [markdown]
# Топ 10 городов по количеству рейсов

# %% [markdown]
# ## 1.4

# %%
count_flights = flights.day.groupby(flights.airline).count()
count_flights
# Out:
# airline
# AA     725984
# AS     172521
# B6     267048
# DL     875881
# EV     571977
# F9      90836
# HA      76272
# MQ     294632
# NK     117379
# OO     588353
# UA     515723
# US     198715
# VX      61903
# WN    1261855
# Name: day, dtype: int64

# %%
top10_airline = airlines.set_index("iata_code").join(count_flights)
top10_airline.day.groupby(top10_airline.airline).sum().sort_values(ascending = False).head(10)
# Out:
# airline
# Southwest Airlines Co.          1261855
# Delta Air Lines Inc.             875881
# American Airlines Inc.           725984
# Skywest Airlines Inc.            588353
# Atlantic Southeast Airlines      571977
# United Air Lines Inc.            515723
# American Eagle Airlines Inc.     294632
# JetBlue Airways                  267048
# US Airways Inc.                  198715
# Alaska Airlines Inc.             172521
# Name: day, dtype: int64

# %% [markdown]
# Топ 10 авиакомпаний по количеству рейсов

# %% [markdown]
# # 2.Исследование данных

# %% [markdown]
# ## 2.1

# %%
flights.departure_delay.min()
# Out:
# -82.0

# %%
min_departure_delay = flights.query('departure_delay == -82.0')
min_departure_delay
# Out:
#          year  month  day  day_of_week airline  flight_number tail_number  \
# 5645762  2015     12   20            7      AS            161      N793AS
#
#         origin_airport destination_airport  scheduled_departure  ...  \
# 5645762            ADK                 ANC                 1715  ...
#
#          arrival_time  arrival_delay  diverted  cancelled  \
# 5645762        1940.0          -80.0         0          0
#
#          cancellation_reason  air_system_delay  security_delay  airline_delay  \
# 5645762                  NaN               NaN             NaN            NaN
#
#          late_aircraft_delay  weather_delay
# 5645762                  NaN            NaN
#
# [1 rows x 31 columns]

# %%
airports.query(" iata_code == 'ADK' ")
# Out:
#   iata_code       airport  city state country  latitude  longitude
# 9       ADK  Adak Airport  Adak    AK     USA  51.87796 -176.64603

# %% [markdown]
# Аэропорт с минимальной задержкой вылета Adak Airport.

# %% [markdown]
# ## 2.2

# %% [markdown]
# Мой аэропорт по списку группы:

# %%
airports.iata_code.iloc()[226]
# Out:
# 'OME'

# %%
airports.query("iata_code == 'OME' ")
# Out:
#     iata_code       airport  city state country  latitude  longitude
# 226       OME  Nome Airport  Nome    AK     USA   64.5122 -165.44525

# %%
airlines_delay= flights[(flights.arrival_delay == 0) & (flights.destination_airport.isin(['OME']))]
airlines_delay.airline.value_counts()
# Out:
# AS    24
# Name: airline, dtype: int64

# %%
airlines_delay = flights[flights.destination_airport.isin(['OME'])]
airlines_delay = pd.DataFrame(airlines_delay.arrival_delay.groupby(airlines_delay.airline).mean().sort_values(ascending = True).head(10))
airlines_delay = airlines_delay.reset_index()
airlines_delay.rename(columns={'arrival_delay': 'arrival_delay_mean'}, inplace=True)
airlines_delay
# Out:
#   airline  arrival_delay_mean
# 0      AS            6.316294

# %%
airlines.query("iata_code == 'AS' ")
# Out:
#   iata_code               airline
# 6        AS  Alaska Airlines Inc.

# %% [markdown]
# Самая пунктуальная авиакомпания на прилет - Alaska Airlines Inc.

# %% [markdown]
# ## 2.3

# %%
airport_taxing_out = flights.taxi_out.groupby(flights.origin_airport).mean()
airport_taxing_in = flights.taxi_in.groupby(flights.destination_airport).mean()
airport_taxing = airport_taxing_out.append(airport_taxing_in)
airport_taxing = airport_taxing.groupby(airport_taxing.index).mean()
airport_taxing.nlargest(12).iloc()[2 : ]
# Out:
# C:\Users\Krasnblu\AppData\Local\Temp\ipykernel_6768\3866383097.py:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   airport_taxing = airport_taxing_out.append(airport_taxing_in)
# JFK      17.876018
# LGA      17.810657
# 12953    17.176806
# ORD      16.378863
# 12266    16.332672
# 12478    16.284931
# 13930    16.200937
# 13930    15.688966
# 11298    15.531195
# 12478    15.375000
# dtype: float64

# %%
airports.query("iata_code == 'JFK' ")
# Out:
#     iata_code                                            airport      city  \
# 166       JFK  John F. Kennedy International Airport (New Yor...  New York
#
#     state country  latitude  longitude
# 166    NY     USA  40.63975  -73.77893

# %% [markdown]
# JFK аэропорт, в котором самолеты проводят в среднем больше всего времени на рулении.
